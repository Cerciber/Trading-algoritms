# %% [markdown]
# # Analisis Alphalens del la variación del algoritmo: Cross sectional Equity Template

# %% [markdown]
# #### Cesar Augusto Torres Ardila

# %% [markdown]
# Alphalens: Realiza análisis de funciones o Factores
#  - Análisis de devoluciones
#  - Análisis del coeficiente de información
#  - Análisis de rotación
#  - Análisis agrupado

# %% [markdown]
# ### Importar Backtests del algoritmo de variación de Cross sectional Equity Template

# %%
algorithmResult = get_backtest('5e407d302eaa07479b68aa4c')
# Out:
# 100% Time:  0:00:25|##########################################################|

# %% [markdown]
# ### Ejecutar una hoja de lágrima completa que incluye gráficos de retornos medios, rotación, coeficiente de información y más

# %%
algorithmResult.create_full_tear_sheet()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-31</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-01-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>24</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.911%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>14.299%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.08%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.34</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.89</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-3.663%</td>
#     </tr>
#     <tr>
# ...
